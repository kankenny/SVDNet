# %%
# %cd /content/drive/MyDrive/da-svd
# !pip install black
# !black -v --diff lib resources study util
# !pip install flake8
# !flake8 -v lib resources study util
# Out:
# /content/drive/MyDrive/da-svd
# ...
# Identified `/content/drive/MyDrive/da-svd` as project root containing a pyproject.toml.
# Using configuration from project root.
# line_length: 88
# extend_exclude: (
#   /.*.txt
#   | .*.md
# )
#
# Found input source directory: "/content/drive/MyDrive/da-svd/lib"
# /content/drive/MyDrive/da-svd/lib/.ipynb_checkpoints ignored: matches the --exclude regular expression
# /content/drive/MyDrive/da-svd/lib/legacy/.ipynb_checkpoints ignored: matches the --exclude regular expression
# /content/drive/MyDrive/da-svd/lib/legacy/README.md ignored: matches the --extend-exclude regular expression
# Found input source directory: "/content/drive/MyDrive/da-svd/resources"
# /content/drive/MyDrive/da-svd/resources/.ipynb_checkpoints ignored: matches the --exclude regular expression
# /content/drive/MyDrive/da-svd/resources/plots/.ipynb_checkpoints ignored: matches the --exclude regular expression
# Found input source directory: "/content/drive/MyDrive/da-svd/study"
# ...

# %%
import os
import sys


if __name__ == "__main__":
    def is_google_colab():
      """Check if the environment is Google Colab."""
      try:
          import google.colab
          return True
      except ImportError:
          return False

    BASE_PATH = os.getcwd()

    if is_google_colab():
        from google.colab import drive

        BASE_PATH = os.path.join(BASE_PATH, "drive")
        drive.mount(BASE_PATH)

        DIR_PATH = os.path.join(BASE_PATH, "MyDrive", "da-svd")
        sys.path.append(DIR_PATH)
    else:
        DIR_PATH = os.path.join(BASE_PATH, "da-svd")
        sys.path.append(DIR_PATH)

#################################################################################

import numpy as np
import tensorflow as tf
import keras

from lib.legacy import svd
from study import plots, datasets
from study.do_study import do_specific_study
from study.visualizations import visualize_all

from util.constants import SEED, PATHS
from util.util import load_image
from util.data_types.trial_detail import TrialDetail

np.random.seed(SEED)
tf.random.set_seed(SEED)
keras.utils.set_random_seed(SEED)

#################################################################################


#################################################################################
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
trial_detail = TrialDetail('mnist', 'all', 1, .9)
do_specific_study(trial_detail)
# Out:
# ...
# Dl Completed...:   0%|          | 0/5 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  sequential_4 (Sequential)   (None, 28, 28, 1)         0
#
#  min_max_normalization (Min  (None, 28, 28, 1)         0
#  MaxNormalization)
#
#  conv2d (Conv2D)             (None, 13, 13, 64)        640
#
#  batch_normalization (Batch  (None, 13, 13, 64)        256
#  Normalization)
#
#  activation (Activation)     (None, 13, 13, 64)        0
#
#  max_pooling2d (MaxPooling2  (None, 7, 7, 64)          0
#  D)
#
#  residual_conv_block (Resid  (None, 7, 7, 64)          74240
#  ualConvBlock)
#
#  flatten (Flatten)           (None, 3136)              0
#
# ...

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)


plots.constant_distortions(img, "cat")

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)


plots.random_gaussian_distortions(img, "cat")

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)


plots.random_uniform_distortions(img, "cat")

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)

plots.plot_all_augmentations(img, "cat")

# %%
visualize_all()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)

plots.mc_complement_mat(img, 'cat')

# %%
#################################################################################

trial_detail = TrialDetail('mnist', 'all', 1, .9)
do_specific_study(trial_detail)

#################################################################################

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)

plots.compare_compressed(img, 'cat')

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)

plots.compare_compressed(img, 'cat')

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)

plots.mc_indiv_r1_mats(img, 'cat')

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)

plots.sc_complement_mat(img, 'cat')

# %%
plots.img_manifold_hypothesis('cat')

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)

plots.sc_indiv_r1_mats(img, 'cat')

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)

plots.mc_cum_r1_mats(img, 'cat')

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)

plots.sc_cum_r1_mats(img, 'cat')

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/digit.jpg'
img = load_image(img_path)

plots.sc_cum_r1_mats(img, 'digit')

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)

plots.indiv_chan(img, 'cat')

# %%
plots.model_architectures()

# %%
img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
img = load_image(img_path)


plots.compare_spectral_vs_rank(img, "cat")

# %%
### Need to align numpy and tf svd implementations first

# img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
# img = load_image(img_path)

# plots.scree(img, 'cat', .5)

# %%
### Need to align numpy and tf svd implementations first

# img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
# img = load_image(img_path)

# plots.compare_svd_tf_sp(img, 'cat')

# %%
### Wrong Implementation

# img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
# img = load_image(img_path)

# plots.sc_noise_vs_svd(img, 'cat')

# %%
### Computationally Intractable

# img_path = f'{PATHS["RESOURCES"]}/test_images/cat.jpg'
# img = load_image(img_path)

# plots.compare_rgb_adj(img, 'cat')
